# %%
import tensorflow as tf
from tensorflow.keras.optimizers import Adam, SGD, RMSprop
from tensorflow.keras.layers import Conv1D, MaxPool1D, Input, Dense, Flatten, Dropout
from tensorflow.keras.models import Sequential
from tensorflow.keras.losses import MSE
from tensorflow.keras.regularizers import L2
from tensorflow.keras.initializers import he_normal, glorot_uniform
from tensorflow.keras.optimizers.schedules import ExponentialDecay, PiecewiseConstantDecay
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
import numpy as np
import pandas as pd
import random
import matplotlib.pyplot as plt
from visualization_utility import plot_data
from prepare_NN_data import prepare_data
from NN_model_plots import plot_learning_curve, plot_random, plot_relative_errors, plot_errors_hist
import h5py
import os
import sys
# Out:
# 2024-08-22 15:46:15.878980: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-08-22 15:46:15.918952: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-08-22 15:46:15.918967: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-08-22 15:46:15.919989: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-08-22 15:46:15.926140: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# [NbConvertApp] Converting notebook visualization_utility.ipynb to script
# [NbConvertApp] Writing 9172 bytes to visualization_utility.py
# [NbConvertApp] Converting notebook prepare_NN_data.ipynb to script
# [NbConvertApp] Writing 8260 bytes to prepare_NN_data.py
# [NbConvertApp] Converting notebook NN_model_plots.ipynb to script
# [NbConvertApp] Writing 5394 bytes to NN_model_plots.py

# %%
print(tf.__version__)
# Out:
# 2.15.0

# %% [markdown]
# <h3>Load the data</h3>

# %%
# Folder where the input and output data are located
NN_data_path = "/fmi/projappl/project_2004400/jamin/data/libradtran_data/NN_data/"

# %%
data_dict = prepare_data(NN_data_path=NN_data_path,
                         output_var="path_rad",
                         train_prop=0.8,
                         val_prop=0.1,
                         test_prop=0.1)
# Out:
# 2024-08-22 15:47:51.242949: E external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:274] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected

# %%
data_dict.keys()
# Out:
# dict_keys(['scaled_X_train', 'scaled_X_val', 'scaled_X_test', 'Y_train_path_rad', 'Y_val_path_rad', 'Y_test_path_rad'])

# %%
scaled_X_train = data_dict["scaled_X_train"]
scaled_X_val = data_dict["scaled_X_val"]
scaled_X_test = data_dict["scaled_X_test"]
Y_train_path_rad = data_dict["Y_train_path_rad"]
Y_val_path_rad = data_dict["Y_val_path_rad"]
Y_test_path_rad = data_dict["Y_test_path_rad"]

# %%
print("############### Training data ###############")
print(f"Shape of scaled_X_train: {scaled_X_train.shape}")
print(f"Shape of Y_train_path_rad: {Y_train_path_rad.shape}")
print()
print("############### Validation data ###############")
print(f"Shape of scaled_X_val: {scaled_X_val.shape}")
print(f"Shape of Y_val_path_rad: {Y_val_path_rad.shape}")
print()
print("############### Test data ###############")
print(f"Shape of scaled_X_test: {scaled_X_test.shape}")
print(f"Shape of Y_test_path_rad: {Y_test_path_rad.shape}")
# Out:
# ############### Training data ###############
# Shape of scaled_X_train: (1382, 53, 1)
# Shape of Y_train_path_rad: (1382, 235002)
#
# ############### Validation data ###############
# Shape of scaled_X_val: (172, 53, 1)
# Shape of Y_val_path_rad: (172, 235002)
#
# ############### Test data ###############
# Shape of scaled_X_test: (174, 53, 1)
# Shape of Y_test_path_rad: (174, 235002)

# %%
path_rad_min = np.min(np.vstack([Y_train_path_rad.numpy(), Y_val_path_rad.numpy(), Y_test_path_rad.numpy()]))
path_rad_max = np.max(np.vstack([Y_train_path_rad.numpy(), Y_val_path_rad.numpy(), Y_test_path_rad.numpy()]))
print(f"Range of path_rad: [{path_rad_min}, {path_rad_max}]")
# Out:
# Range of path_rad: [0.0010383955668658018, 45.767967224121094]

# %% [markdown]
# <h3>Train the model</h3>

# %%
def model(X_train, Y_train, X_val, Y_val, num_epochs: int, batch_size: int, output_var_name):
    """
    Builds, compiles, fits the neural network model. 
    
    Args:
    X -- the input dataset
    Y -- the output dataset
    num_epochs -- the number of epochs
    batch_size -- the batch size
    val_data -- validation data to be used in the training process of the NN
    output_var_name -- name of the output variable that the NN model predicts
    
    Prints:
    - train MSE
    - validation MSE
    
    Returns:
    model -- the fitted neural network model.
    loss_history -- the loss history of the fitted neural network model.
    """
    #tf.random.set_seed(42)
    
    # Architecture of the NN model
    model = Sequential([
        
        Input(shape=(53, 1)),
        
        Conv1D(filters=64, 
               kernel_size=3, 
               strides=1, 
               padding="valid",
               kernel_initializer=he_normal(),
               activation="relu"),
        
        Conv1D(filters=32, 
               kernel_size=3, 
               strides=1,
               padding="valid",
               kernel_initializer=he_normal(),
               activation="relu"),
        
        Conv1D(filters=10, 
               kernel_size=3,
               strides=1,
               padding="valid",
               kernel_initializer=he_normal(),
               activation="relu"),
        
        Flatten(),
        
        Dense(units=60, 
              kernel_initializer=he_normal(),
              activation="relu"),
        
        Dense(units=50, 
              kernel_initializer=he_normal(),
              activation="relu"),
        
        Dense(units=40, 
              kernel_initializer=he_normal(),
              activation="relu"),
        
        Dense(units=235002, 
              kernel_initializer=glorot_uniform(), 
              activation="linear"),
    ])
    
    # Lower the learning rate every 5 epochs
    lr_schedule = ExponentialDecay(initial_learning_rate=0.01,
                                   decay_steps=220,
                                   decay_rate=0.96,
                                   staircase=True)
    
    # This callback will stop the training when there is no improvement in
    # the validation mse for 3 consecutive epochs, and restore the weights 
    # from the epoch with the best value of the monitored quantity (val_loss)
    early_stopping = EarlyStopping(monitor="val_loss",
                                   patience=5,
                                   restore_best_weights=True,
                                   start_from_epoch=0)
    
    # Compile the model
    model.compile(loss=MSE,
                  optimizer=Adam(learning_rate=lr_schedule,
                                 beta_1=0.9,
                                 beta_2=0.999),
                  metrics=["mse"])
    
    # Fit the model
    loss_history = model.fit(X_train, 
                             Y_train, 
                             epochs=num_epochs, 
                             batch_size=batch_size, 
                             validation_data=(X_val, Y_val),
                             callbacks=[early_stopping])
    
    # Train error
    train_loss, train_mse = model.evaluate(X_train, Y_train)
    
    # Validation error
    val_loss, val_mse = model.evaluate(X_val, Y_val)
    
    print("########################################")
    print(f"Train MSE: {train_mse}")
    print(f"Validation MSE: {val_mse}")
    print("########################################")
    
    return model, loss_history

# %%
NN_model, loss_history = model(X_train=scaled_X_train, 
                               Y_train=Y_train_path_rad,
                               X_val=scaled_X_val,
                               Y_val=Y_val_path_rad,
                               num_epochs=25,
                               batch_size=32,
                               output_var_name="path_rad")
# Out:
# Epoch 1/25
# 44/44 [==============================] - 3s 40ms/step - loss: 106.3413 - mse: 106.3413 - val_loss: 12.6917 - val_mse: 12.6917
# Epoch 2/25
# 44/44 [==============================] - 2s 38ms/step - loss: 6.1551 - mse: 6.1551 - val_loss: 9.0414 - val_mse: 9.0414
# Epoch 3/25
# 44/44 [==============================] - 2s 39ms/step - loss: 2.5724 - mse: 2.5724 - val_loss: 1.4419 - val_mse: 1.4419
# Epoch 4/25
# 44/44 [==============================] - 2s 36ms/step - loss: 1.3575 - mse: 1.3575 - val_loss: 1.2166 - val_mse: 1.2166
# Epoch 5/25
# 44/44 [==============================] - 2s 39ms/step - loss: 1.1232 - mse: 1.1232 - val_loss: 1.1094 - val_mse: 1.1094
# Epoch 6/25
# 44/44 [==============================] - 2s 37ms/step - loss: 0.8164 - mse: 0.8164 - val_loss: 0.5919 - val_mse: 0.5919
# Epoch 7/25
# 44/44 [==============================] - 2s 37ms/step - loss: 0.5370 - mse: 0.5370 - val_loss: 0.4259 - val_mse: 0.4259
# Epoch 8/25
# 44/44 [==============================] - 2s 38ms/step - loss: 0.5607 - mse: 0.5607 - val_loss: 0.3477 - val_mse: 0.3477
# Epoch 9/25
# 44/44 [==============================] - 2s 38ms/step - loss: 0.2979 - mse: 0.2979 - val_loss: 0.4597 - val_mse: 0.4597
# Epoch 10/25
# 44/44 [==============================] - 2s 38ms/step - loss: 0.3515 - mse: 0.3515 - val_loss: 0.2501 - val_mse: 0.2501
# Epoch 11/25
# 44/44 [==============================] - 2s 45ms/step - loss: 0.1960 - mse: 0.1960 - val_loss: 0.1958 - val_mse: 0.1958
# Epoch 12/25
# 44/44 [==============================] - 2s 38ms/step - loss: 0.1923 - mse: 0.1923 - val_loss: 0.1601 - val_mse: 0.1601
# Epoch 13/25
# 44/44 [==============================] - 2s 37ms/step - loss: 0.1590 - mse: 0.1590 - val_loss: 0.1412 - val_mse: 0.1412
# Epoch 14/25
# 44/44 [==============================] - 2s 39ms/step - loss: 0.1392 - mse: 0.1392 - val_loss: 0.0998 - val_mse: 0.0998
# Epoch 15/25
# 44/44 [==============================] - 2s 37ms/step - loss: 0.1115 - mse: 0.1115 - val_loss: 0.2191 - val_mse: 0.2191
# Epoch 16/25
# 44/44 [==============================] - 2s 37ms/step - loss: 0.1492 - mse: 0.1492 - val_loss: 0.0806 - val_mse: 0.0806
# Epoch 17/25
# 44/44 [==============================] - 2s 36ms/step - loss: 0.0956 - mse: 0.0956 - val_loss: 0.1339 - val_mse: 0.1339
# Epoch 18/25
# 44/44 [==============================] - 1s 34ms/step - loss: 0.0780 - mse: 0.0780 - val_loss: 0.0448 - val_mse: 0.0448
# Epoch 19/25
# 44/44 [==============================] - 2s 35ms/step - loss: 0.0631 - mse: 0.0631 - val_loss: 0.1136 - val_mse: 0.1136
# Epoch 20/25
# 44/44 [==============================] - 2s 35ms/step - loss: 0.0893 - mse: 0.0893 - val_loss: 0.0536 - val_mse: 0.0536
# Epoch 21/25
# 44/44 [==============================] - 2s 34ms/step - loss: 0.0505 - mse: 0.0505 - val_loss: 0.0447 - val_mse: 0.0447
# Epoch 22/25
# 44/44 [==============================] - 2s 37ms/step - loss: 0.0633 - mse: 0.0633 - val_loss: 0.0402 - val_mse: 0.0402
# Epoch 23/25
# 44/44 [==============================] - 2s 36ms/step - loss: 0.0492 - mse: 0.0492 - val_loss: 0.0489 - val_mse: 0.0489
# Epoch 24/25
# 44/44 [==============================] - 2s 36ms/step - loss: 0.1441 - mse: 0.1441 - val_loss: 0.0831 - val_mse: 0.0831
# Epoch 25/25
# 44/44 [==============================] - 2s 35ms/step - loss: 0.0804 - mse: 0.0804 - val_loss: 0.0339 - val_mse: 0.0339
# 44/44 [==============================] - 0s 7ms/step - loss: 0.0309 - mse: 0.0309
# 6/6 [==============================] - 0s 7ms/step - loss: 0.0339 - mse: 0.0339
# ########################################
# Train MSE: 0.03088819421827793
# Validation MSE: 0.03391058370471001
# ########################################

# %% [markdown]
# <h3>Evaluate the model on the validation data</h3>

# %% [markdown]
# - The term 'true' in the plots refers to the output values obtained from libradtran RT model.
# - The term 'emulated' refers to the predicted values obtained from the fitted neural network model.

# %%
path_rad_preds = NN_model.predict(scaled_X_val)
# Out:
# 6/6 [==============================] - 0s 5ms/step

# %%
plot_learning_curve(loss_history, "path_rad")

# %%
plot_random(path_rad_preds, scaled_X_val, Y_val_path_rad, "path_rad")

# %%
plot_errors_hist(path_rad_preds, scaled_X_val, Y_val_path_rad)

# %%
# Plot emulator results vs. true (libradtran RT model) values
plot_data(y_true=Y_val_path_rad,
          y_pred=path_rad_preds,
          title="Emulator result",
          x_label="path_rad true",
          y_label="path_rad emulated",
          error_bar_on=True)

# %% [markdown]
# <h3>Errors</h3>
#
# Errors are calculated as $\, Y_{preds} - Y_{true}. \,$ This means that
#
# - if the error is positive, the model prediction is larger than the true value
# - if the error is negative, the model prediction is smaller than the true value.
#
# <h3>Bias</h3>
#
# Bias is calculated as $\, \text{median} (Y_{preds} - Y_{true}). \,$ This means that
# - if $\, \text{Bias} > 0, \,$ the predicted values are generally larger than the true values \
# $\, \boldsymbol{\rightarrow} \,$ the model systematically **overestimates** the predicted values
# - if $\, \text{Bias} < 0, \,$ the predicted values are generally smaller than the true values \
# $\, \boldsymbol{\rightarrow} \,$ the model systematically **underestimates** the predicted values

# %% [markdown]
# <h3>Save the predictions</h3>

# %%
def save_HDF5(Y, save_loc, file_name):
    """
    Saves the given NumPy array into the desired location in HDF5 format.
    
    Args:
        Y: NumPy array
        save_loc: the path to the desired saving location
        file_name: name of the saved file
        
    Returns:
        None.
    """
    full_path = save_loc + file_name
    with h5py.File(full_path, "w") as hf:
        hf.create_dataset("output_data", data=Y)

# %%
#save_loc = "/fmi/projappl/project_2004400/jamin/data/libradtran_data/NN_data/"

# %%
#file_name = "path_rad_preds.h5"
#save_HDF5(Y=path_rad_preds, save_loc=save_loc, file_name=file_name)

# %% [markdown]
# <h3>Save the RT model validation data</h3>

# %%
#file_name = "path_rad_val_RT.h5"
#save_HDF5(Y=Y_val_path_rad, save_loc=save_loc, file_name=file_name)

# %% [markdown]
# <h3>Evaluate the model on the test data</h3>

# %%
path_rad_preds_test = NN_model.predict(scaled_X_test)
# Out:
# 6/6 [==============================] - 0s 5ms/step

# %%
plot_random(path_rad_preds_test, scaled_X_test, Y_test_path_rad, "edir")

# %%
plot_errors_hist(path_rad_preds_test, scaled_X_test, Y_test_path_rad)

# %%
# Plot emulator results vs. true (libradtran RT model) values
plot_data(y_true=Y_test_path_rad,
          y_pred=path_rad_preds_test,
          title="Emulator result",
          x_label="path_rad true",
          y_label="path_rad emulated",
          error_bar_on=True)
