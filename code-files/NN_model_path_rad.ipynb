# %%
import tensorflow as tf
from tensorflow.keras.optimizers import Adam, SGD, RMSprop
from tensorflow.keras.layers import Conv1D, MaxPool1D, Input, Dense, Flatten, Dropout
from tensorflow.keras.models import Sequential
from tensorflow.keras.losses import MSE
from tensorflow.keras.regularizers import L2
from tensorflow.keras.initializers import he_normal, glorot_uniform
from tensorflow.keras.optimizers.schedules import ExponentialDecay, PiecewiseConstantDecay
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
import numpy as np
import pandas as pd
import random
import matplotlib.pyplot as plt
from visualization_utility import plot_data
from prepare_NN_data import prepare_data
from NN_model_plots import plot_learning_curve, plot_random, plot_relative_errors, plot_errors_hist
import h5py
import os
import sys
# Out:
# 2024-08-22 16:03:40.367031: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-08-22 16:03:40.405577: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-08-22 16:03:40.405594: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-08-22 16:03:40.406522: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-08-22 16:03:40.412390: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# [NbConvertApp] Converting notebook visualization_utility.ipynb to script
# [NbConvertApp] Writing 9172 bytes to visualization_utility.py
# [NbConvertApp] Converting notebook prepare_NN_data.ipynb to script
# [NbConvertApp] Writing 8260 bytes to prepare_NN_data.py
# [NbConvertApp] Converting notebook NN_model_plots.ipynb to script
# [NbConvertApp] Writing 5394 bytes to NN_model_plots.py

# %%
print(tf.__version__)
# Out:
# 2.15.0

# %% [markdown]
# <h3>Load the data</h3>

# %%
# Folder where the input and output data are located
NN_data_path = "/fmi/projappl/project_2004400/jamin/data/libradtran_data/NN_data/"

# %%
data_dict = prepare_data(NN_data_path=NN_data_path,
                         output_var="path_rad",
                         train_prop=0.8,
                         val_prop=0.1,
                         test_prop=0.1)
# Out:
# 2024-08-22 16:05:17.762658: E external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:274] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected

# %%
data_dict.keys()
# Out:
# dict_keys(['scaled_X_train', 'scaled_X_val', 'scaled_X_test', 'Y_train_path_rad', 'Y_val_path_rad', 'Y_test_path_rad'])

# %%
scaled_X_train = data_dict["scaled_X_train"]
scaled_X_val = data_dict["scaled_X_val"]
scaled_X_test = data_dict["scaled_X_test"]
Y_train = data_dict["Y_train_path_rad"]
Y_val = data_dict["Y_val_path_rad"]
Y_test = data_dict["Y_test_path_rad"]

# %%
print("############### Training data ###############")
print(f"Shape of scaled_X_train: {scaled_X_train.shape}")
print(f"Shape of Y_train: {Y_train.shape}")
print()
print("############### Validation data ###############")
print(f"Shape of scaled_X_val: {scaled_X_val.shape}")
print(f"Shape of Y_val: {Y_val.shape}")
print()
print("############### Test data ###############")
print(f"Shape of scaled_X_test: {scaled_X_test.shape}")
print(f"Shape of Y_test: {Y_test.shape}")
# Out:
# ############### Training data ###############
# Shape of scaled_X_train: (1382, 53, 1)
# Shape of Y_train: (1382, 235002)
#
# ############### Validation data ###############
# Shape of scaled_X_val: (172, 53, 1)
# Shape of Y_val: (172, 235002)
#
# ############### Test data ###############
# Shape of scaled_X_test: (174, 53, 1)
# Shape of Y_test: (174, 235002)

# %%
path_rad_min = np.min(np.vstack([Y_train.numpy(), Y_val.numpy(), Y_test.numpy()]))
path_rad_max = np.max(np.vstack([Y_train.numpy(), Y_val.numpy(), Y_test.numpy()]))
print(f"Range of path_rad: [{path_rad_min}, {path_rad_max}]")
# Out:
# Range of path_rad: [0.0010383955668658018, 45.767967224121094]

# %% [markdown]
# <h3>Train the model</h3>

# %%
def model(X_train, Y_train, X_val, Y_val, num_epochs: int, batch_size: int, output_var_name):
    """
    Builds, compiles, fits the neural network model. 
    
    Args:
    X -- the input dataset
    Y -- the output dataset
    num_epochs -- the number of epochs
    batch_size -- the batch size
    val_data -- validation data to be used in the training process of the NN
    output_var_name -- name of the output variable that the NN model predicts
    
    Prints:
    - train MSE
    - validation MSE
    
    Returns:
    model -- the fitted neural network model.
    loss_history -- the loss history of the fitted neural network model.
    """
    #tf.random.set_seed(42)
    
    # Architecture of the NN model
    model = Sequential([
        
        Input(shape=(53, 1)),
        
        Conv1D(filters=64, 
               kernel_size=3, 
               strides=1, 
               padding="valid",
               kernel_initializer=he_normal(),
               activation="relu"),
        
        Dropout(rate=0.1),
        
        Conv1D(filters=32, 
               kernel_size=3, 
               strides=1,
               padding="valid",
               kernel_initializer=he_normal(),
               activation="relu"),
        
        Conv1D(filters=10, 
               kernel_size=3,
               strides=1,
               padding="valid",
               kernel_initializer=he_normal(),
               activation="relu"),
        
        Flatten(),
        
        Dense(units=60, 
              kernel_initializer=he_normal(),
              kernel_regularizer=L2(0.01),
              activation="relu"),
        
        Dense(units=50, 
              kernel_initializer=he_normal(),
              activation="relu"),
        
        Dense(units=40, 
              kernel_initializer=he_normal(),
              activation="relu"),
        
        Dense(units=235002, 
              kernel_initializer=glorot_uniform(), 
              activation="linear"),
    ])
    
    # Lower the learning rate every 5 epochs
    lr_schedule = ExponentialDecay(initial_learning_rate=0.01,
                                   decay_steps=220,
                                   decay_rate=0.96,
                                   staircase=True)
    
    # This callback will stop the training when there is no improvement in
    # the validation mse for 3 consecutive epochs, and restore the weights 
    # from the epoch with the best value of the monitored quantity (val_loss)
    early_stopping = EarlyStopping(monitor="val_loss",
                                   patience=5,
                                   restore_best_weights=True,
                                   start_from_epoch=0)
    
    # Compile the model
    model.compile(loss=MSE,
                  optimizer=Adam(learning_rate=lr_schedule,
                                 beta_1=0.9,
                                 beta_2=0.999),
                  metrics=["mse"])
    
    # Fit the model
    loss_history = model.fit(X_train, 
                             Y_train, 
                             epochs=num_epochs, 
                             batch_size=batch_size, 
                             validation_data=(X_val, Y_val),
                             callbacks=[early_stopping])
    
    # Train error
    train_loss, train_mse = model.evaluate(X_train, Y_train)
    
    # Validation error
    val_loss, val_mse = model.evaluate(X_val, Y_val)
    
    print("########################################")
    print(f"Train MSE: {train_mse}")
    print(f"Validation MSE: {val_mse}")
    print("########################################")
    
    return model, loss_history

# %%
NN_model, loss_history = model(X_train=scaled_X_train, 
                               Y_train=Y_train,
                               X_val=scaled_X_val,
                               Y_val=Y_val,
                               num_epochs=25,
                               batch_size=32,
                               output_var_name="path_rad")
# Out:
# Epoch 1/25
# 44/44 [==============================] - 3s 38ms/step - loss: 48.4680 - mse: 48.1144 - val_loss: 7.1756 - val_mse: 6.8979
# Epoch 2/25
# 44/44 [==============================] - 2s 35ms/step - loss: 3.4310 - mse: 3.1808 - val_loss: 2.1382 - val_mse: 1.9066
# Epoch 3/25
# 44/44 [==============================] - 2s 35ms/step - loss: 1.8129 - mse: 1.5852 - val_loss: 1.2623 - val_mse: 1.0287
# Epoch 4/25
# 44/44 [==============================] - 2s 35ms/step - loss: 1.0943 - mse: 0.8588 - val_loss: 0.7631 - val_mse: 0.5333
# Epoch 5/25
# 44/44 [==============================] - 1s 34ms/step - loss: 0.7890 - mse: 0.5680 - val_loss: 1.2100 - val_mse: 0.9992
# Epoch 6/25
# 44/44 [==============================] - 2s 42ms/step - loss: 0.9307 - mse: 0.7263 - val_loss: 0.4678 - val_mse: 0.2750
# Epoch 7/25
# 44/44 [==============================] - 2s 35ms/step - loss: 0.6708 - mse: 0.4851 - val_loss: 0.4158 - val_mse: 0.2376
# Epoch 8/25
# 44/44 [==============================] - 2s 35ms/step - loss: 0.5649 - mse: 0.3924 - val_loss: 1.1251 - val_mse: 0.9589
# Epoch 9/25
# 44/44 [==============================] - 1s 34ms/step - loss: 0.7765 - mse: 0.6094 - val_loss: 0.6787 - val_mse: 0.5163
# Epoch 10/25
# 44/44 [==============================] - 2s 35ms/step - loss: 0.4944 - mse: 0.3387 - val_loss: 0.8290 - val_mse: 0.6802
# Epoch 11/25
# 44/44 [==============================] - 2s 35ms/step - loss: 0.4947 - mse: 0.3479 - val_loss: 0.2865 - val_mse: 0.1448
# Epoch 12/25
# 44/44 [==============================] - 2s 34ms/step - loss: 0.4144 - mse: 0.2776 - val_loss: 1.4284 - val_mse: 1.2958
# Epoch 13/25
# 44/44 [==============================] - 1s 34ms/step - loss: 0.5648 - mse: 0.4332 - val_loss: 0.4121 - val_mse: 0.2827
# Epoch 14/25
# 44/44 [==============================] - 1s 34ms/step - loss: 0.5861 - mse: 0.4600 - val_loss: 0.3833 - val_mse: 0.2598
# Epoch 15/25
# 44/44 [==============================] - 2s 35ms/step - loss: 0.3668 - mse: 0.2463 - val_loss: 0.2165 - val_mse: 0.0991
# Epoch 16/25
# 44/44 [==============================] - 2s 34ms/step - loss: 0.3905 - mse: 0.2753 - val_loss: 0.2629 - val_mse: 0.1507
# Epoch 17/25
# 44/44 [==============================] - 1s 34ms/step - loss: 0.3556 - mse: 0.2448 - val_loss: 0.5318 - val_mse: 0.4223
# Epoch 18/25
# 44/44 [==============================] - 2s 34ms/step - loss: 0.5272 - mse: 0.4201 - val_loss: 0.7116 - val_mse: 0.6060
# Epoch 19/25
# 44/44 [==============================] - 2s 34ms/step - loss: 0.3753 - mse: 0.2708 - val_loss: 0.1790 - val_mse: 0.0757
# Epoch 20/25
# 44/44 [==============================] - 1s 33ms/step - loss: 0.3698 - mse: 0.2685 - val_loss: 0.4978 - val_mse: 0.3980
# Epoch 21/25
# 44/44 [==============================] - 2s 35ms/step - loss: 0.5641 - mse: 0.4661 - val_loss: 1.0836 - val_mse: 0.9871
# Epoch 22/25
# 44/44 [==============================] - 2s 35ms/step - loss: 0.5025 - mse: 0.4060 - val_loss: 0.2568 - val_mse: 0.1615
# Epoch 23/25
# 44/44 [==============================] - 1s 34ms/step - loss: 0.3393 - mse: 0.2462 - val_loss: 0.2717 - val_mse: 0.1806
# Epoch 24/25
# 44/44 [==============================] - 2s 35ms/step - loss: 0.4362 - mse: 0.3457 - val_loss: 0.2011 - val_mse: 0.1112
# 44/44 [==============================] - 0s 7ms/step - loss: 0.1737 - mse: 0.0705
# 6/6 [==============================] - 0s 6ms/step - loss: 0.1790 - mse: 0.0757
# ########################################
# Train MSE: 0.07045446336269379
# Validation MSE: 0.07569057494401932
# ########################################

# %% [markdown]
# <h3>Evaluate the model on the validation data</h3>

# %% [markdown]
# - The term 'true' in the plots refers to the output values obtained from libradtran RT model.
# - The term 'emulated' refers to the predicted values obtained from the fitted neural network model.

# %%
val_preds = NN_model.predict(scaled_X_val)
# Out:
# 6/6 [==============================] - 0s 4ms/step

# %%
plot_learning_curve(loss_history, "path_rad")

# %%
plot_random(val_preds, scaled_X_val, Y_val, "path_rad")

# %%
plot_errors_hist(val_preds, scaled_X_val, Y_val)

# %%
# Plot emulator results vs. true (libradtran RT model) values
plot_data(y_true=Y_val,
          y_pred=val_preds,
          title="Emulator result",
          x_label="path_rad true",
          y_label="path_rad emulated",
          error_bar_on=True)

# %% [markdown]
# <h3>Errors</h3>
#
# Errors are calculated as $\, Y_{preds} - Y_{true}. \,$ This means that
#
# - if the error is positive, the model prediction is larger than the true value
# - if the error is negative, the model prediction is smaller than the true value.
#
# <h3>Bias</h3>
#
# Bias is calculated as $\, \text{median} (Y_{preds} - Y_{true}). \,$ This means that
# - if $\, \text{Bias} > 0, \,$ the predicted values are generally larger than the true values \
# $\, \boldsymbol{\rightarrow} \,$ the model systematically **overestimates** the predicted values
# - if $\, \text{Bias} < 0, \,$ the predicted values are generally smaller than the true values \
# $\, \boldsymbol{\rightarrow} \,$ the model systematically **underestimates** the predicted values

# %% [markdown]
# <h3>Save the predictions</h3>

# %%
def save_HDF5(Y, save_loc, file_name):
    """
    Saves the given NumPy array into the desired location in HDF5 format.
    
    Args:
        Y: NumPy array
        save_loc: the path to the desired saving location
        file_name: name of the saved file
        
    Returns:
        None.
    """
    full_path = save_loc + file_name
    with h5py.File(full_path, "w") as hf:
        hf.create_dataset("output_data", data=Y)

# %%
#save_loc = "/fmi/projappl/project_2004400/jamin/data/libradtran_data/NN_data/"

# %%
#file_name = "path_rad_preds.h5"
#save_HDF5(Y=path_rad_preds, save_loc=save_loc, file_name=file_name)

# %% [markdown]
# <h3>Save the RT model validation data</h3>

# %%
#file_name = "path_rad_val_RT.h5"
#save_HDF5(Y=Y_val_path_rad, save_loc=save_loc, file_name=file_name)

# %% [markdown]
# <h3>Evaluate the model on the test data</h3>

# %%
test_preds = NN_model.predict(scaled_X_test)
# Out:
# 6/6 [==============================] - 0s 4ms/step

# %%
plot_random(test_preds, scaled_X_test, Y_test, "edir")

# %%
plot_errors_hist(test_preds, scaled_X_test, Y_test)

# %%
# Plot emulator results vs. true (libradtran RT model) values
plot_data(y_true=Y_test,
          y_pred=test_preds,
          title="Emulator result",
          x_label="path_rad true",
          y_label="path_rad emulated",
          error_bar_on=True)
